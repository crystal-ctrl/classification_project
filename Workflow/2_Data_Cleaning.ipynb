# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime, date
from ast import literal_eval

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
engine = create_engine("sqlite:///data/kickstarter.db")
df = pd.read_sql('SELECT * FROM data;', engine)
print(df.shape)
df.head()
# Out:
# (870114, 38)
#   backers_count                                              blurb  \
# 0            56  The Backyard will be a community garden in Lak...
# 1             1  Modern London is home to a poverty driven ambi...
# 2            35  Announcing a twist of our original party game ...
# 3            37                     Overstock card renovation plan
# 4             0  Straight Up Photography is a project to bring ...
#
#                                             category converted_pledged_amount  \
# 0  {"id":305,"name":"Community Gardens","slug":"f...                     5507
# 1  {"id":293,"name":"Drama","slug":"film & video/...                        1
# 2  {"id":273,"name":"Playing Cards","slug":"games...                     1119
# 3  {"id":273,"name":"Playing Cards","slug":"games...                     1236
# 4  {"id":277,"name":"Nature","slug":"photography/...                        0
#
#   country country_displayable_name  created_at  \
# 0      US        the United States  1487809696
# 1      GB       the United Kingdom  1469267948
# 2      US        the United States  1519236804
# 3      HK                Hong Kong  1566103145
# 4      US        the United States  1422146426
#
#                                              creator currency currency_symbol  \
# 0  {"id":2723718,"name":"The Backyard","is_regist...      USD               $
# 1  {"id":2084330677,"name":"Lee Bartlett","is_reg...      GBP               £
# 2  {"id":1978836496,"name":"I Can't Even! Game","...      USD               $
# 3  {"id":1320915715,"name":"yandawei","is_registe...      HKD               $
# 4  {"id":109408228,"name":"Ivan Straight","is_reg...      USD               $
#
#    ...                                               slug  \
# 0  ...                      the-backyard-community-garden
# 1  ...                                    rocks-to-stocks
# 2  ...  i-cant-even-a-party-game-expansion-pack-ice-to-go
# 3  ...            fantasy-creature-stock-modified-edition
# 4  ...                            straight-up-photography
#
#                                           source_url spotlight staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      true      false
# 1  https://www.kickstarter.com/discover/categorie...     false      false
# 2  https://www.kickstarter.com/discover/categorie...      true      false
# 3  https://www.kickstarter.com/discover/categorie...      true      false
# 4  https://www.kickstarter.com/discover/categorie...     false      false
#
#         state state_changed_at static_usd_rate  \
# 0  successful       1491789637               1
# 1      failed       1471870195      1.32234378
# 2  successful       1532956446               1
# 3  successful       1570200330      0.12748679
# 4    canceled       1422243394               1
#
#                                                 urls    usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...        5507.77  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...     1.32234378  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...         1119.0  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...  1236.49437621  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...            0.0  domestic
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'country_displayable_name', 'created_at', 'creator',
#        'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'friends',
#        'fx_rate', 'goal', 'id', 'is_backing', 'is_starrable', 'is_starred',
#        'launched_at', 'location', 'name', 'permissions', 'photo', 'pledged',
#        'profile', 'slug', 'source_url', 'spotlight', 'staff_pick', 'state',
#        'state_changed_at', 'static_usd_rate', 'urls', 'usd_pledged',
#        'usd_type'],
#       dtype='object')

# %%
# get rid of the "column-headers rows"
df = df[df.created_at != "created_at"]
df.shape
# Out:
# (869877, 38)

# %%
df = df.drop(columns=['creator', 'country_displayable_name', 'currency_symbol', 'currency_trailing_code', 'current_currency', 
                            'disable_communication','friends', 'is_backing', 'is_starrable', 'is_starred', 
                            'permissions', 'photo', 'profile', 'source_url', 'urls'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 869877 entries, 0 to 870113
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             869877 non-null  object
#  1   blurb                     869877 non-null  object
#  2   category                  869877 non-null  object
#  3   converted_pledged_amount  869877 non-null  object
#  4   country                   869877 non-null  object
#  5   created_at                869877 non-null  object
#  6   currency                  869877 non-null  object
#  7   deadline                  869877 non-null  object
#  8   fx_rate                   869877 non-null  object
#  9   goal                      869877 non-null  object
#  10  id                        869877 non-null  object
#  11  launched_at               869877 non-null  object
#  12  location                  869877 non-null  object
#  13  name                      869877 non-null  object
#  14  pledged                   869877 non-null  object
#  15  slug                      869877 non-null  object
#  16  spotlight                 869877 non-null  object
#  17  staff_pick                869877 non-null  object
#  18  state                     869877 non-null  object
#  19  state_changed_at          869877 non-null  object
#  20  static_usd_rate           869877 non-null  object
#  21  usd_pledged               869877 non-null  object
#  22  usd_type                  869877 non-null  object
# dtypes: object(23)
# memory usage: 159.3+ MB

# %%
# first looking at the ratio of successful and failed here
df.state.value_counts()
# Out:
# successful    513286
# failed        297213
# canceled       36090
# live           23288
# Name: state, dtype: int64

# %%
df['state'] = df.state.astype(str)
# Only interested in success/fail champaigns
df = df[(df.state == "successful") | (df.state == "failed")]
df.shape
# Out:
# (810499, 23)

# %%
# Converting datetime objects
df['created_at'] = df['created_at'].astype(int)
df['created_at'] = pd.to_datetime(df['created_at'],unit='s')

df['deadline'] = df['deadline'].astype(int)
df['deadline'] = pd.to_datetime(df['deadline'], unit='s')

df['launched_at'] = df['launched_at'].astype(int)
df['launched_at'] = pd.to_datetime(df['launched_at'],unit='s')

df['state_changed_at'] = df['state_changed_at'].astype(int)
df['state_changed_at'] = pd.to_datetime(df['state_changed_at'],unit='s')

# %%
# df['duration'] = df.deadline - df.launched_at

# %%
# check for duplicates
df.id.value_counts()
# Out:
# 430731749     9
# 2028673237    9
# 1684513733    8
# 563445716     8
# 1434058810    8
#              ..
# 750731768     1
# 1243134418    1
# 1164987667    1
# 1586158795    1
# 120722291     1
# Name: id, Length: 189162, dtype: int64

# %%
df[df.id == '2028673237']
# Out:
#        backers_count                                              blurb  \
# 3661             219  Personalized pillow that fits every type of sl...
# 96273            219  Personalized pillow that fits every type of sl...
# 162383           219  Personalized pillow that fits every type of sl...
# 233190           219  Personalized pillow that fits every type of sl...
# 331971           219  Personalized pillow that fits every type of sl...
# 468787           219  Personalized pillow that fits every type of sl...
# 581029           219  Personalized pillow that fits every type of sl...
# 738967           219  Personalized pillow that fits every type of sl...
# 856122           219  Personalized pillow that fits every type of sl...
#
#                                                  category  \
# 3661    {"id":28,"name":"Product Design","slug":"desig...
# 96273   {"id":28,"name":"Product Design","slug":"desig...
# 162383  {"id":28,"name":"Product Design","slug":"desig...
# 233190  {"id":28,"name":"Product Design","slug":"desig...
# 331971  {"id":28,"name":"Product Design","slug":"desig...
# 468787  {"id":28,"name":"Product Design","slug":"desig...
# 581029  {"id":28,"name":"Product Design","slug":"desig...
# 738967  {"id":28,"name":"Product Design","analytics_na...
# 856122  {"id":28,"name":"Product Design","analytics_na...
#
#        converted_pledged_amount country          created_at currency  \
# 3661                      36557      NL 2019-09-21 07:53:37      EUR
# 96273                     36557      NL 2019-09-21 07:53:37      EUR
# 162383                    36557      NL 2019-09-21 07:53:37      EUR
# 233190                    36557      NL 2019-09-21 07:53:37      EUR
# 331971                    36557      NL 2019-09-21 07:53:37      EUR
# 468787                    36557      NL 2019-09-21 07:53:37      EUR
# 581029                    36557      NL 2019-09-21 07:53:37      EUR
# 738967                    36557      NL 2019-09-21 07:53:37      EUR
# 856122                    36557      NL 2019-09-21 07:53:37      EUR
#
#                   deadline     fx_rate   goal  ...             name pledged  \
# 3661   2020-10-30 09:48:30  1.21497973  10000  ...  Franky's Pillow   31270
# 96273  2020-10-30 09:48:30  1.21497973  10000  ...  Franky's Pillow   31270
# 162383 2020-10-30 09:48:30  1.21497973  10000  ...  Franky's Pillow   31270
# 233190 2020-10-30 09:48:30  1.21220937  10000  ...  Franky's Pillow   31270
# 331971 2020-10-30 09:48:30  1.21220937  10000  ...  Franky's Pillow   31270
# 468787 2020-10-30 09:48:30  1.19592048  10000  ...  Franky's Pillow   31270
# 581029 2020-10-30 09:48:30  1.19592048  10000  ...  Franky's Pillow   31270
# 738967 2020-10-30 09:48:30  1.19752161  10000  ...  Franky's Pillow   31270
# 856122 2020-10-30 09:48:30  1.19752161  10000  ...  Franky's Pillow   31270
#
#                   slug spotlight staff_pick       state    state_changed_at  \
# 3661    frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 96273   frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 162383  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 233190  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 331971  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 468787  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 581029  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 738967  frankys-pillow      true      false  successful 2020-10-30 09:48:30
# 856122  frankys-pillow      true      false  successful 2020-10-30 09:48:30
#
#        static_usd_rate         usd_pledged       usd_type
# 3661        1.18473306  37046.602786199997       domestic
# 96273       1.18473306  37046.602786199997       domestic
# 162383      1.18473306  37046.602786199997       domestic
# 233190      1.18473306  37046.602786199997       domestic
# 331971      1.18473306  37046.602786199997  international
# 468787      1.18473306  37046.602786199997  international
# 581029      1.18473306  37046.602786199997  international
# 738967      1.18473306  37046.602786199997  international
# 856122      1.18473306  37046.602786199997  international
#
# [9 rows x 23 columns]

# %%
df.drop_duplicates(subset=['id', 'state'], inplace=True)
df.shape
# Out:
# (189162, 23)

# %%
# Categories - Main category and sub_category
c = df.category.apply(literal_eval)
main_category = []
for i, d in enumerate(c):
    try:
        main_category.append(d['parent_name'])
    except:
        main_category.append(np.nan)
df['main_category'] = main_category
df.main_category.value_counts()
# Out:
# Film & Video    25683
# Music           25432
# Technology      19254
# Art             19232
# Publishing      18814
# Food            14321
# Games           12690
# Fashion         10083
# Comics           7192
# Design           6892
# Photography      5894
# Crafts           5181
# Theater          4708
# Journalism       3402
# Dance            1716
# Name: main_category, dtype: int64

# %%
sub_category = []
for i, name in enumerate(d['name'] for d in c):
    sub_category.append(name)
df['sub_category'] = sub_category
df.sub_category.value_counts()
# Out:
# Web               3805
# Tabletop Games    3275
# Comedy            2925
# Comic Books       2602
# Product Design    2600
#                   ...
# Quilts              87
# Residencies         85
# Letterpress         84
# Chiptune            50
# Taxidermy           10
# Name: sub_category, Length: 161, dtype: int64

# %%
# Country - needs to condense the list
df.country.value_counts()
# Out:
# US    130527
# GB     21365
# CA      8829
# AU      4399
# DE      3487
# FR      2826
# MX      2770
# IT      2467
# ES      2201
# NL      1648
# SE      1380
# HK      1322
# DK       851
# NZ       826
# SG       767
# CH       685
# BE       587
# IE       580
# JP       554
# AT       470
# NO       449
# LU        62
# PL        59
# GR        35
# SI        16
# Name: country, dtype: int64

# %%
dic = {"DK": "OTHER", "NZ": "OTHER", "SG": "OTHER", "CH": "OTHER", "BE": "OTHER", "IE": "OTHER",
      "JP": "OTHER", "AT": "OTHER", "NO": "OTHER", "LU": "OTHER", "PL": "OTHER", "GR": "OTHER",
      "SI": "OTHER"}
df = df.replace({"country": dic})
df.country.value_counts()
# Out:
# US       130527
# GB        21365
# CA         8829
# OTHER      5941
# AU         4399
# DE         3487
# FR         2826
# MX         2770
# IT         2467
# ES         2201
# NL         1648
# SE         1380
# HK         1322
# Name: country, dtype: int64

# %%
# Currency - needs to convert all goal values to USD
df.currency.value_counts()
# Out:
# USD    130527
# GBP     21365
# EUR     14516
# CAD      8829
# AUD      4399
# MXN      2770
# SEK      1335
# HKD      1322
# NZD       826
# DKK       824
# SGD       767
# CHF       666
# JPY       554
# NOK       439
# PLN        23
# Name: currency, dtype: int64

# %%
df['goal'] = df.goal.astype(float)
df['fx_rate'] = df.fx_rate.astype(float)
df['goal_usd'] = df.goal * df.fx_rate
df.head()
# Out:
#   backers_count                                              blurb  \
# 0            56  The Backyard will be a community garden in Lak...
# 1             1  Modern London is home to a poverty driven ambi...
# 2            35  Announcing a twist of our original party game ...
# 3            37                     Overstock card renovation plan
# 5            14  I want to learn how to dye fabric! Follow me a...
#
#                                             category converted_pledged_amount  \
# 0  {"id":305,"name":"Community Gardens","slug":"f...                     5507
# 1  {"id":293,"name":"Drama","slug":"film & video/...                        1
# 2  {"id":273,"name":"Playing Cards","slug":"games...                     1119
# 3  {"id":273,"name":"Playing Cards","slug":"games...                     1236
# 5  {"id":289,"name":"Textiles","slug":"art/textil...                      766
#
#   country          created_at currency            deadline   fx_rate     goal  \
# 0      US 2017-02-23 00:28:16      USD 2017-04-10 02:00:36  1.000000   5227.0
# 1      GB 2016-07-23 09:59:08      GBP 2016-08-22 12:49:55  1.367950  35000.0
# 2      US 2018-02-21 18:13:24      USD 2018-07-30 13:14:04  1.000000   1000.0
# 3      HK 2019-08-18 04:39:05      HKD 2019-10-04 14:45:30  0.128969   8000.0
# 5      US 2018-01-06 20:19:17      USD 2018-02-10 02:29:02  1.000000    550.0
#
#    ... spotlight staff_pick       state    state_changed_at static_usd_rate  \
# 0  ...      true      false  successful 2017-04-10 02:00:37               1
# 1  ...     false      false      failed 2016-08-22 12:49:55      1.32234378
# 2  ...      true      false  successful 2018-07-30 13:14:06               1
# 3  ...      true      false  successful 2019-10-04 14:45:30      0.12748679
# 5  ...      true      false  successful 2018-02-10 02:29:04               1
#
#      usd_pledged  usd_type main_category       sub_category     goal_usd
# 0        5507.77  domestic          Food  Community Gardens   5227.00000
# 1     1.32234378  domestic  Film & Video              Drama  47878.24160
# 2         1119.0  domestic         Games      Playing Cards   1000.00000
# 3  1236.49437621  domestic         Games      Playing Cards   1031.74888
# 5          766.0  domestic           Art           Textiles    550.00000
#
# [5 rows x 26 columns]

# %%
df.usd_type.value_counts()
# Out:
# domestic         183869
# international      5083
# null                210
# Name: usd_type, dtype: int64

# %%
# checking for NaN
df.isna().sum()
# Out:
# backers_count                  0
# blurb                          0
# category                       0
# converted_pledged_amount       0
# country                        0
# created_at                     0
# currency                       0
# deadline                       0
# fx_rate                        0
# goal                           0
# id                             0
# launched_at                    0
# location                       0
# name                           0
# pledged                        0
# slug                           0
# spotlight                      0
# staff_pick                     0
# state                          0
# state_changed_at               0
# static_usd_rate                0
# usd_pledged                    0
# usd_type                       0
# main_category               8668
# sub_category                   0
# goal_usd                       0
# dtype: int64

# %%
# fill main_category NaN with sub_category 
df[df.main_category.isna()]['sub_category'].value_counts()
# Out:
# Dance           1378
# Art             1259
# Crafts          1130
# Music            790
# Journalism       723
# Food             574
# Theater          555
# Photography      456
# Comics           364
# Technology       363
# Publishing       336
# Design           249
# Film & Video     244
# Fashion          146
# Games            101
# Name: sub_category, dtype: int64

# %%
df.main_category.fillna(df.sub_category, inplace=True)
df.isna().sum()
# Out:
# backers_count               0
# blurb                       0
# category                    0
# converted_pledged_amount    0
# country                     0
# created_at                  0
# currency                    0
# deadline                    0
# fx_rate                     0
# goal                        0
# id                          0
# launched_at                 0
# location                    0
# name                        0
# pledged                     0
# slug                        0
# spotlight                   0
# staff_pick                  0
# state                       0
# state_changed_at            0
# static_usd_rate             0
# usd_pledged                 0
# usd_type                    0
# main_category               0
# sub_category                0
# goal_usd                    0
# dtype: int64

# %%
kickstarter = df[['id', 'goal_usd', 'country', 'created_at', 'deadline',  'launched_at', 'state_changed_at',
                  'spotlight','staff_pick', 'main_category', 'sub_category', 'blurb', 'state']]
kickstarter.head()
# Out:
#            id     goal_usd country          created_at            deadline  \
# 0  1560919980   5227.00000      US 2017-02-23 00:28:16 2017-04-10 02:00:36
# 1  1441173176  47878.24160      GB 2016-07-23 09:59:08 2016-08-22 12:49:55
# 2  1907302929   1000.00000      US 2018-02-21 18:13:24 2018-07-30 13:14:04
# 3   520777940   1031.74888      HK 2019-08-18 04:39:05 2019-10-04 14:45:30
# 5  2087823414    550.00000      US 2018-01-06 20:19:17 2018-02-10 02:29:02
#
#           launched_at    state_changed_at spotlight staff_pick main_category  \
# 0 2017-03-11 03:00:36 2017-04-10 02:00:37      true      false          Food
# 1 2016-07-23 12:49:55 2016-08-22 12:49:55     false      false  Film & Video
# 2 2018-06-30 13:14:04 2018-07-30 13:14:06      true      false         Games
# 3 2019-09-04 14:45:30 2019-10-04 14:45:30      true      false         Games
# 5 2018-01-11 02:29:02 2018-02-10 02:29:04      true      false           Art
#
#         sub_category                                              blurb  \
# 0  Community Gardens  The Backyard will be a community garden in Lak...
# 1              Drama  Modern London is home to a poverty driven ambi...
# 2      Playing Cards  Announcing a twist of our original party game ...
# 3      Playing Cards                     Overstock card renovation plan
# 5           Textiles  I want to learn how to dye fabric! Follow me a...
#
#         state
# 0  successful
# 1      failed
# 2  successful
# 3  successful
# 5  successful

# %%
kickstarter.to_csv("./data/kickstarter.csv", index= False)
